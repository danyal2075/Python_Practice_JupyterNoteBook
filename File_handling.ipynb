# %%
with open("./detail.txt", 'r+') as f:
    a = f.readlines()
    print(a)
    b = ['hamzaMehran']
    print(b)
    c = a + b
    print(c)
    d= ' '.join(c)
    f.seek(0)
    f.write(d)
# Out:
# ['sohaildanyal']
# ['hamzaMehran']
# ['sohaildanyal', 'hamzaMehran']

# %%
with open('./detail1.txt', 'w') as f:
    f.write('sohail danyal')

# %%
with open('./detail1.txt', 'a') as f:
    f.write('\nshamza mehran')

# %%
with open('./detail1.txt', 'r') as f:
    b = f.readline()
    print(b)
# Out:
# sohail danyal

# %%
with open('./detail1.txt', 'r') as f:
    b = f.readlines()[:1]
    print(b)
# Out:
# ['sohail danyal\n']

# %%
with open('./detail1.txt', 'a+') as f:
    b = f.readlines()
    f.write('Pakistan')
    print(b)
# Out:
# []

# %%
with open('./detail1.txt', 'a+') as f:
    
    f.write('hello world')
    f.seek(0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./pic.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (530, 800)

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread('./pics.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
# Out:
# (408, 612, 3)
